# %% [markdown]
# # Utilisation

# %% [markdown]
# ## Initialiser un projet

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent   # car notebook est dans notebook/ et pas dans le root du projet
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from cartograpy.project import *

# Initialiser un projet avec un CRS et des dossiers par défaut
projet = Project(
    path="./mon_projet/",   # répertoire racine du projet
    data_dir="data",        # dossier des données
    output_dir="output",    # dossier des résultats
    crs="EPSG:4326"         # système de coordonnées (WGS 84)
)
projet.init()
# Out:
# ✅ Projet initialisé dans : c:\Users\Ordinateur\OneDrive\cartograpy\notebooks\mon_projet
#    📁 c:\Users\Ordinateur\OneDrive\cartograpy\notebooks\mon_projet\data
#    📁 c:\Users\Ordinateur\OneDrive\cartograpy\notebooks\mon_projet\output
# 'c:\\Users\\Ordinateur\\OneDrive\\cartograpy\\notebooks\\mon_projet'

# %% [markdown]
# ## Lire et écrire des données vectorielles

# %%
from cartograpy.data import *

# %%
# Lire un fichier vectoriel (GeoJSON, Shapefile, GeoPackage, etc.)
vecteur = load("../data/vector/gadm41_CIV.gpkg")
vecteur.head()
# Out:
# c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\pyogrio\geopandas.py:382: UserWarning: More than one layer found in 'gadm41_CIV.gpkg': 'ADM_ADM_0' (default), 'ADM_ADM_1', 'ADM_ADM_2', 'ADM_ADM_3', 'ADM_ADM_4'. Specify layer parameter to avoid this warning.
#   result = read_func(
#   GID_0        COUNTRY                                           geometry
# 0   CIV  Côte d'Ivoire  MULTIPOLYGON (((-4.21958 5.21986, -4.22375 5.2...

# %%
# Lire un fichier GPX (traces GPS)
gpx_track = load("../data/vector/données tracées.gpx")
gpx_track.head()
# Out:
#                       name   cmt  desc   src link1_href link1_text link1_type  \
# 0  2023-01-11 16:55:07WILF  None  None  None       None       None       None
# 1  2023-01-11 17:13:12YLIA  None  None  None       None       None       None
# 2      2023-01-12 09:13:53  None  None  None       None       None       None
# 3      H023-01-11 15:57:26  None  None  None       None       None       None
#
#   link2_href link2_text link2_type  number  type  \
# 0       None       None       None     NaN  None
# 1       None       None       None     NaN  None
# 2       None       None       None     NaN  None
# 3       None       None       None     NaN  None
#
#                                             geometry
# 0  MULTILINESTRING ((-2.79985 8.04028, -2.79985 8...
# 1  MULTILINESTRING ((-2.80003 8.03988, -2.80003 8...
# 2  MULTILINESTRING ((-2.79987 8.04027, -2.79987 8...
# 3  MULTILINESTRING ((-2.79978 8.04016, -2.79981 8...

# %%
# Lire un fichier GPX (traces GPS)
gpx_waypoints = load("../data/vector/données tracées.gpx", layer="waypoints")  # spécifier la couche "waypoints" pour les points d'intérêt
gpx_waypoints.head()
# Out:
#    ele                      time  magvar  geoidheight          name   cmt  \
# 0  NaN 2023-01-11 16:13:24+00:00     NaN          NaN           002  None
# 1  NaN 2023-01-11 16:46:41+00:00     NaN          NaN         CYBER  None
# 2  NaN 2023-01-11 17:02:02+00:00     NaN          NaN  ORANGE MONEY  None
# 3  NaN 2023-01-11 17:22:36+00:00     NaN          NaN           003  None
# 4  NaN 2023-01-11 17:24:22+00:00     NaN          NaN           ADO  None
#
#    desc                  src link1_href link1_text  ... vdop pdop  \
# 0  None  garmin GPSMAP 64x S       None       None  ...  NaN  NaN
# 1  None  garmin GPSMAP 64x S       None       None  ...  NaN  NaN
# 2  None  garmin GPSMAP 64x S       None       None  ...  NaN  NaN
# 3  None  garmin GPSMAP 64x S       None       None  ...  NaN  NaN
# 4  None  garmin GPSMAP 64x S       None       None  ...  NaN  NaN
#
#   ageofdgpsdata dgpsid  gpxx_lat  gpxx_lon gpxx_y_proj  gpxx_x_proj  \
# 0           NaN    NaN  8.040172 -2.799787    8.040172    -2.799787
# 1           NaN    NaN  8.040315 -2.799868    8.040315    -2.799868
# 2           NaN    NaN  8.039868 -2.800023    8.039868    -2.800023
# 3           NaN    NaN  8.040243 -2.799854    8.040243    -2.799854
# 4           NaN    NaN  8.040297 -2.799831    8.040297    -2.799831
#
#             gpxx_ltime                  geometry
# 0  2023/01/11 16:13:24  POINT (-2.79979 8.04017)
# 1  2023/01/11 16:46:41  POINT (-2.79987 8.04032)
# 2  2023/01/11 17:02:02  POINT (-2.80002 8.03987)
# 3  2023/01/11 17:22:36  POINT (-2.79985 8.04024)
# 4  2023/01/11 17:24:22   POINT (-2.79983 8.0403)
#
# [5 rows x 29 columns]

# %%
# Lire un fichier raster (GeoTIFF)
raster = load("../data/raster/DEM.tif")
print("CRS :", raster.crs)
print("Dimensions :", raster.width, "x", raster.height)
print("Emprise :", raster.bounds)
raster.close()
# Out:
# CRS : EPSG:4326
# Dimensions : 3398 x 2011
# Emprise : BoundingBox(left=-4.980416667, bottom=8.305416667, right=-2.14875, top=9.98125)

# %% [markdown]
# ## Sauvegarder des données dans le projet

# %%
projet.add_data(gpx_track, "geojson", filename="données_tracées_track")
# Out:
# ✅ Fichier sauvegardé : c:\Users\Ordinateur\OneDrive\cartograpy\notebooks\mon_projet\data\données_tracées_track.geojson
# ✅ Données ajoutées : c:\Users\Ordinateur\OneDrive\cartograpy\notebooks\mon_projet\data\données_tracées_track.geojson
# 'c:\\Users\\Ordinateur\\OneDrive\\cartograpy\\notebooks\\mon_projet\\data\\données_tracées_track.geojson'

# %%
projet.add_data(raster, "tif", filename="données_raster", raster_meta=True)
# Out:
# ✅ Fichier sauvegardé : c:\Users\Ordinateur\OneDrive\cartograpy\notebooks\mon_projet\data\données_raster.tif
# ✅ Données ajoutées : c:\Users\Ordinateur\OneDrive\cartograpy\notebooks\mon_projet\data\données_raster.tif
# 'c:\\Users\\Ordinateur\\OneDrive\\cartograpy\\notebooks\\mon_projet\\data\\données_raster.tif'

# %%
save (vecteur, "geojson", "./mon_projet/data/limite_ci")
# Out:
# ✅ Fichier sauvegardé : c:\Users\Ordinateur\OneDrive\cartograpy\notebooks\mon_projet\data\limite_ci.geojson
# 'c:\\Users\\Ordinateur\\OneDrive\\cartograpy\\notebooks\\mon_projet\\data\\limite_ci.geojson'

# %% [markdown]
# ## Carte de situation de Yamoussoukro

# %% [markdown]
# ## Carte choroplèthe

# %%
# Recharger le module mapper après correction
import importlib
import cartograpy.mapper
importlib.reload(cartograpy.mapper)
from cartograpy.mapper import Map

# %%
# Carte choroplèthe colorée selon une colonne du GeoDataFrame
m = Map(
    title="Carte administrative de la Côte d'Ivoire",
    figsize="A4",
)

# Ajouter les polygones avec coloration par colonne
m.add_polygons(
    vecteur,
    label="Régions",
    column="GID_1",
    cmap="Set3",
    edgecolor="black",
    linewidth=0.5,
    alpha=0.8,
    legend=True,
)

# Ajouter la mini-carte de situation
m.add_inset(
    bounds=vecteur.total_bounds.tolist(),
    box_color="red",
    box_linewidth=2,
    location="lower right",
)

m.add_gridlines()
m.add_scale_bar(length=100, location="lower right", units="km")
m.add_north_arrow()
m.show()
# Out:
# 📄 Format de papier: A4 (landscape) - Dimensions: 210 x 297 mm - Figure: 11.7" x 8.3"
# 🔍 Carte de situation ajoutée (map-utils)
# 🧭 Flèche du Nord ajoutée (map-utils)
# 📊 Centrage intelligent appliqué:
#    Format: A4 (landscape)
#    Ratio figure: 1.41
#    Ratio données: 0.96
#    Étendue: [-10.96, -0.14, 3.72, 11.37]
# 🛑Element de légende ajouté None
# ✅ Légende personnalisée créée avec 1 éléments

# %% [markdown]
# ## Carte interactive (WebMap)

# %%
from cartograpy.mapper import WebMap

# Créer une carte interactive
wm = WebMap()

# Ajouter les limites administratives
wm.add_layer(vecteur, tooltip_columns=["COUNTRY"])

# Ajouter les waypoints GPS
wm.add_layer(gpx_waypoints, tooltip_columns=["name"])

wm.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\folium\folium.py:358, in Map._repr_html_(self, **kwargs)
#     356     self._parent = None
#     357 else:
# --> 358     out = self._parent._repr_html_(**kwargs)
#     359 return out
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\branca\element.py:414, in Figure._repr_html_(self, **kwargs)
#     412 def _repr_html_(self, **kwargs) -> str:
#     413     """Displays the Figure in a Jupyter notebook."""
# --> 414     html = escape(self.render(**kwargs))
#     415     if self.height is None:
#     416         iframe = (
#     417             '<div style="width:{width};">'
#     418             '<div style="position:relative;width:100%;height:0;padding-bottom:{ratio};">'  # noqa
#    (...)    424             "</div></div>"
#     425         ).format(html=html, width=self.width, ratio=self.ratio)
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\branca\element.py:409, in Figure.render(self, **kwargs)
#     407 """Renders the HTML representation of the element."""
#     408 for name, child in self._children.items():
# --> 409     child.render(**kwargs)
#     410 return self._template.render(this=self, kwargs=kwargs)
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\folium\elements.py:46, in JSCSSMixin.render(self, **kwargs)
#      43 for name, url in self.default_css:
#      44     figure.header.add_child(CssLink(url), name=name)
# ---> 46 super().render(**kwargs)
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\folium\map.py:73, in Class.render(self, **kwargs)
#      64     # A bit weird. I tried adding IncludeStatement directly to both
#      65     # figure and script, but failed. So we render this ourself.
#      66     figure.script.add_child(
#      67         Element(stmt._template.render(this=stmt, kwargs=self.includes)),
#      68         # make sure each class include gets rendered only once
#    (...)     71         index=-1,
#      72     )
# ---> 73 super().render(**kwargs)
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\branca\element.py:740, in MacroElement.render(self, **kwargs)
#     737     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     739 for name, element in self._children.items():
# --> 740     element.render(**kwargs)
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\folium\features.py:871, in GeoJson.render(self, **kwargs)
#     869     if self.highlight:
#     870         self.highlight_map = mapper.get_highlight_map(self.highlight_function)
# --> 871 super().render()
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\folium\map.py:137, in Layer.render(self, **kwargs)
#     129 if self.show:
#     130     self.add_child(
#     131         ElementAddToElement(
#     132             element_name=self.get_name(),
#    (...)    135         name=self.get_name() + "_add",
#     136     )
# --> 137 super().render(**kwargs)
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\folium\map.py:73, in Class.render(self, **kwargs)
#      64     # A bit weird. I tried adding IncludeStatement directly to both
#      65     # figure and script, but failed. So we render this ourself.
#      66     figure.script.add_child(
#      67         Element(stmt._template.render(this=stmt, kwargs=self.includes)),
#      68         # make sure each class include gets rendered only once
#    (...)     71         index=-1,
#      72     )
# ---> 73 super().render(**kwargs)
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\branca\element.py:737, in MacroElement.render(self, **kwargs)
#     735 script = self._template.module.__dict__.get("script", None)
#     736 if script is not None:
# --> 737     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     739 for name, element in self._children.items():
#     740     element.render(**kwargs)
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\jinja2\runtime.py:770, in Macro.__call__(self, *args, **kwargs)
#     764 elif len(args) > self._argument_count:
#     765     raise TypeError(
#     766         f"macro {self.name!r} takes not more than"
#     767         f" {len(self.arguments)} argument(s)"
#     768     )
# --> 770 return self._invoke(arguments, autoescape)
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\jinja2\runtime.py:784, in Macro._invoke(self, arguments, autoescape)
#     781 if self._environment.is_async:
#     782     return self._async_invoke(arguments, autoescape)  # type: ignore
# --> 784 rv = self._func(*arguments)
#     786 if autoescape:
#     787     rv = Markup(rv)
#
# File <template>:265, in macro(l_1_this, l_1_kwargs)
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\jinja2\filters.py:1721, in do_tojson(eval_ctx, value, indent)
#    1718     kwargs = kwargs.copy()
#    1719     kwargs["indent"] = indent
# -> 1721 return htmlsafe_json_dumps(value, dumps=dumps, **kwargs)
#
# File c:\Users\Ordinateur\OneDrive\cartograpy\.venv\Lib\site-packages\jinja2\utils.py:669, in htmlsafe_json_dumps(obj, dumps, **kwargs)
#     665 if dumps is None:
#     666     dumps = json.dumps
#     668 return markupsafe.Markup(
# --> 669     dumps(obj, **kwargs)
#     670     .replace("<", "\\u003c")
#     671     .replace(">", "\\u003e")
#     672     .replace("&", "\\u0026")
#     673     .replace("'", "\\u0027")
#     674 )
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\json\encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\json\encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type Timestamp is not JSON serializable

# %% [markdown]
# ## Traitement des données vectorielles

# %%
from cartograpy.processing import centroids, fusion, join, add_column

# Calculer les centroïdes des régions
centres = centroids(vecteur)
centres.head()

# %%
# Ajouter une colonne calculée (superficie en km²)
vecteur_avec_surface = add_column(
    vecteur.to_crs(epsg=32630),  # UTM zone 30N pour la CIV
    "superficie_km2",
    lambda df: df.geometry.area / 1e6,
).to_crs(epsg=4326)

vecteur_avec_surface[["NAME_1", "superficie_km2"]].head()

# %%
# Jointure spatiale : associer les waypoints GPS aux régions
resultat_jointure = join(
    (gpx_waypoints, "points GPS"),
    (vecteur, "régions"),
)
resultat_jointure.head()

# %% [markdown]
# ## Téléchargement de données géographiques

# %%
from cartograpy.data import Bound, OSM

# Télécharger les limites d'un pays via GeoBoundaries
bound = Bound()
civ = bound.get_country("Côte d'Ivoire")
civ.head()

# %%
# Télécharger des données OSM (écoles de Yamoussoukro)
osm = OSM()
ecoles = osm.get_data("Yamoussoukro, Côte d'Ivoire", tags={"amenity": "school"}, data_type="points")
ecoles.head()

# %%
# Visualiser les écoles sur une carte interactive
wm2 = WebMap(title="Écoles de Yamoussoukro")
wm2.add_layer(ecoles, tooltip_columns=["name"])
wm2.show()
